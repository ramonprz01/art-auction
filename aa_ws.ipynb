# %%
# load the libraries you'll need
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
# create a conection with the website
webpage_resp = requests.get('http://www.ifar.org/catalogues_raisonnes.php?alpha=&searchtype=artist&published=1&inPrep=1&artist=&author=')

# %%
# assign the content of the website to a new variable using the method, .content
webpage = webpage_resp.content

# %%
prefix = "http://www.ifar.org/"

# %%
# instantiate a BeatifulSoup object with the content and the type of parser you'll use
soup = BeautifulSoup(webpage, "html.parser")

# %%
for child in soup.tr.children:
    print(child.string)
# Out:
# Name
#
#
# Birth Year
#
#
# Birth Place
#
#
# Death Year
#
#
# Death Place

# %%
#print(soup.find_all("tr"))

# %%
#print(soup.find_all(attrs={'class':'g_center_name'}))

# %%
#print(soup.select(".g_center_birth_place"))

# %%
soup_links = soup.find_all("a")
links = []

# %%
for a in soup_links:
    links.append(prefix+a["href"])

# %%
#This worked but remember that the first ones are all uselinks, useful ones will need to be retrieved
print(links)
# Out:
# ['http://www.ifar.org/../..', 'http://www.ifar.org/home.php', 'http://www.ifar.org/educational_resources.php', 'http://www.ifar.org/art_law.php', 'http://www.ifar.org/cat_rais.php', 'http://www.ifar.org/provenance_guide.php', 'http://www.ifar.org/collectors_corner.php', 'http://www.ifar.org/authentication.php', 'http://www.ifar.org/publications.php', 'http://www.ifar.org/news.php', 'http://www.ifar.org/programs_events.php', 'http://www.ifar.org/support_ifar.php', 'http://www.ifar.org/become_a_member.php', 'http://www.ifar.org/subscribe_journal.php', 'http://www.ifar.org/donation.php', 'http://www.ifar.org/advertise.php', 'http://www.ifar.org/artist_name.php?nameid=1563&published=1&inPrep=1&author=', 'http://www.ifar.org/artist_name.php?nameid=1396&published=1&inPrep=1&author=', 'http://www.ifar.org/artist_name.php?nameid=1397&published=1&inPrep=1&author=', 'http://www.ifar.org/artist_name.php?nameid=3073&published=1&inPrep=1&author=', 'http://www.ifar.org/artist_name.php?nameid=2030&
# ...

# %%
#follow each link:
for link in links:
    webpage = requests.get(link)
    turtle = BeautifulSoup(webpage.content, "html.parser")
    turtle_name = turtle.select(".name")[0].get_text()
  
    stats = turtle.find("ul")
    stats_text = stats.get_text("|")
    turtle_data[turtle_name] = stats_text.split("|")

# %%
print(soup.get_text("|"))
# Out:
# |
# |
# |International Foundation for Art Research (IFAR)-Catalogues Raisonnés|
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
#         function GlossaryDefinition(label,instance)
#         {
#          // AJAX call to get definition of "label" from glossary table
#          if (window.XMLHttpRequest)
#            {// code for IE7+, Firefox, Chrome, Opera, Safari
#             xmlhttp=new XMLHttpRequest();
#            }
#          else
#            {// code for IE6, IE5
#            xmlhttp=new ActiveXObject("Microsoft.XMLHTTP");
#            }
#
#          xmlhttp.onreadystatechange=function()
#            {
#             if (xmlhttp.readyState==4 && xmlhttp.status==200)
#              {
#               infopop.childNodes[instance].innerHTML=xmlhttp.responseText;
#              }
#             }
#
#          xmlhttp.open("GET","getGlossaryDefinition.php?term="+ encodeURI(label),true);
#          xmlhttp.send();
#
# ...
